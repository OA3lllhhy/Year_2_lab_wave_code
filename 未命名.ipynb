# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact

# %%
T_1 = 50 - (240 / np.pi) * np.sin(np.pi * x /120)
T_3 = 50 - (240 / np.pi) * np.sin(np.pi * x /120) - (80 / np.pi) * np.sin(np.pi * x /40)
x = np.linspace(-200,200)
plt.xlim(-200,200)
plt.ylim(-50,200)
plt.plot(x,T_1,label="n=1")
plt.plot(x,T_3,label="n=3")
plt.legend()
plt.grid()
plt.show()
